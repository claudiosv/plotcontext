# %% [markdown]
# # Boxplot count annotations
#
# `PolarsPlotContext` can annotate a grouped/hued boxplot with the number of observations in each box, either centered on the box or offset to the side via `label_offset`.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# %%
import polars as pl

from plotcontext import PolarsPlotContext

df = pl.DataFrame(
    {
        "group": ["a"] * 6 + ["b"] * 6,
        "sub": (["x", "x", "x", "y", "y", "y"]) * 2,
        "value": [1, 2, 3, 4, 5, 6, 2, 3, 4, 5, 6, 7],
    }
)

# %%
with PolarsPlotContext(title="Count-annotated boxplot", y_label="value") as ctx:
    ctx.sns.boxplot(
        data=df,
        x="group",
        y="value",
        hue="sub",
        annotate="x",
        label_offset=0.2,
    )
